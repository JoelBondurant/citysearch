# %% [markdown]
# # City Search Jupyter Notebook
# ---

# %%
import imp
import functools
import numpy as np
import pandas as pd
#
import citysearch
imp.reload(citysearch);

# %% [markdown]
# ### Initial unindexed data exploration:
# ---

# %%
df = citysearch.DataLoader().to_dataframe()
df.iloc[[0,1,2,-3,-2,-1]]
# Out:
#             id geonameid                 name            asciiname  \
# 0            1   3039154            El Tarter            El Tarter
# 1            2   3039163  Sant Julià de Lòria  Sant Julia de Loria
# 2            3   3039604       Pas de la Casa       Pas de la Casa
# 142308  142309    895417               Banket               Banket
# 142309  142310   1085510              Epworth              Epworth
# 142310  142311   1106542          Chitungwiza          Chitungwiza
#
#                                                  altnames   latitude  \
# 0                                    Ehl Tarter,Эл Тартер  42.579521
# 1       San Julia,San Julià,Sant Julia de Loria,Sant J...  42.463718
# 2                           Pas de la Kasa,Пас де ла Каса  42.542770
# 142308                             Banket,Banket Junction -17.383329
# 142309                                            Epworth -17.889999
# 142310  Chitungviza,Chitungwiza,Citungviza,Gorad Chytu... -18.012739
#
#         longitude feat_class feat_code country_code   cc2 admin1_code  \
# 0        1.653620          P       PPL           AD  None          02
# 1        1.491290          P      PPLA           AD  None          06
# 2        1.733610          P       PPL           AD  None          03
# 142308  30.400000          P       PPL           ZW  None          05
# 142309  31.147499          P      PPLX           ZW  None          10
# 142310  31.075550          P       PPL           ZW  None          10
#
#        admin2_code admin3_code admin4_code population elevation   dem  \
# 0             None        None        None       1052      None  1721
# 1             None        None        None       8022      None   921
# 2             None        None        None       2363      2050  2106
# 142308        None        None        None       9641      None  1277
# 142309        None        None        None     123250      None  1508
# 142310        None        None        None     340360      None  1435
#
#               timezone    modified
# 0       Europe/Andorra  2012-11-03
# 1       Europe/Andorra  2013-11-23
# 2       Europe/Andorra  2008-06-09
# 142308   Africa/Harare  2013-03-12
# 142309   Africa/Harare  2012-01-19
# 142310   Africa/Harare  2012-01-20

# %%
df.shape
# Out:
# (142311, 20)

# %%
df.isnull().sum()
# Out:
# id                   0
# geonameid            0
# name                 0
# asciiname            1
# altnames         22512
# latitude             0
# longitude            0
# feat_class           0
# feat_code            0
# country_code        43
# cc2             138063
# admin1_code         53
# admin2_code      46027
# admin3_code      90037
# admin4_code     121802
# population           0
# elevation       120913
# dem                  0
# timezone             0
# modified             0
# dtype: int64

# %%
[(colname, df[colname].str.len().min(), df[colname].str.len().max()) for colname in df.columns if df[colname].dtype == np.object]
# Out:
# [('geonameid', nan, nan),
#  ('name', 1, 66),
#  ('asciiname', 1.0, 66.0),
#  ('altnames', 2.0, 589259.0),
#  ('feat_class', 1, 1),
#  ('feat_code', 3, 5),
#  ('country_code', 2.0, 2.0),
#  ('cc2', 2.0, 5.0),
#  ('admin1_code', 1.0, 8.0),
#  ('admin2_code', 1.0, 47.0),
#  ('admin3_code', 1.0, 10.0),
#  ('admin4_code', 2.0, 20.0),
#  ('population', nan, nan),
#  ('elevation', nan, nan),
#  ('dem', nan, nan),
#  ('timezone', 9, 30),
#  ('modified', 10, 10)]

# %%
[(colname, df[colname].min(), df[colname].max()) for colname in df.columns if df[colname].dtype == np.int]
# Out:
# [('id', 1, 142311)]

# %%
[(colname, df[colname].min(), df[colname].max()) for colname in df.columns if df[colname].dtype == np.float32]
# Out:
# [('latitude', -77.846001, 78.223343), ('longitude', -179.12198, 179.36452)]

# %%
altnames = df[['altnames']].copy()
altnames['charlen'] = altnames.altnames.str.len()
altnames['wordlen'] = altnames.altnames.str.count(',') + 1
print(altnames.charlen.sum(), altnames.wordlen.sum())
altnames.sort_values('charlen', ascending = False)[:10]
# Out:
# 8012677.0 715190.0
#                                                  altnames   charlen  wordlen
# 135461  ksbridzh,Aksbridz,Aksbridzas,Aksbridzh,Aksbrid...  589259.0  15717.0
# 134154  rving,Erving,Irving,Irvingas,abingu,ayrfyngh,a...  196814.0   5364.0
# 59053   rvin,Ehrvin,Irbhinn,Irvin,Irvine i Ayrshire,OE...  115552.0   2271.0
# 57799   kfijld,awkfyld,Ъкфийлд,اوکفیلد\t50.96948\t0.09...   22976.0    398.0
# 57597   stradgunlajs,Ystradgunlais,Ystradgynlais,Ъстра...   13723.0    352.0
# 137631  plend,Apland,CCB,Magnolia Villa,North Ontario,...    4713.0    204.0
# 125053  sparta,Baris,Gorad ysparta,Hamid,Hamid-Abad,Ha...    4059.0    170.0
# 73536   Adonai-jireh,Aelia Capitolina,Al Quds,Al-Kuds,...    2425.0    251.0
# 120869  Gorad Petrapaulausk-Kamchacki,Kamchatkataagy P...    1736.0     71.0
# 137232  Angelopolis,Cuidad De Los Angelos,Cuidad De lo...    1619.0    113.0

# %% [markdown]
# ### Quick and dirty search implementation (unindexed, unoptimized):

# %%
def city_search(afield, avalue):
    """ Lookup a city by key value pair."""
    return df[df[afield] == avalue]

def geo_dist(lat1, lon1, lat2, lon2):
    """ Exact geo distance in kilometers (haversine). """
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    hs1 = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
    hs = 2 * np.arcsin(np.sqrt(hs1))
    km = 6367 * hs
    return km

# %%
def proximity_search(afield, avalue, k = 10, dt = None):
    """ Locate k nearest cities to specified city key."""
    # locate city:
    rec = city_search(afield, avalue)
    lat1, lon1 = (rec.latitude.iloc[0], rec.longitude.iloc[0])
    # Filter cities with approximate surface patch based
    # on fixed deviations of angular coordinates:
    if dt is None:
        if k < 10**3:
            dt = 2
        else:
            dt = min(180/6*np.log10(k+1)+1, 180)
    dg = df
    # North Pole patch:
    if lat1 > 80:
        latmin = 80 - 4*dt
        latmax = 90
        dg = dg[(dg.latitude >= latmin) & (dg.latitude <= latmax)]
    # South Pole patch:
    elif lat1 < -80:
        latmin = -90
        latmax = -80 + 4*dt
        dg = dg[(dg.latitude >= latmin) & (dg.latitude <= latmax)]
    # Prime meridian patch:
    elif (lon1 + dt > 180) or (lon1 - dt < -180):
        latmin = lat1 - dt
        latmax = lat1 + dt
        dg = dg[(dg.latitude >= latmin) & (dg.latitude <= latmax)]
        dg = dg[(dg.longitude <= -180 + dt) | (dg.longitude >= 180 - dt)]
    # Regular patch:
    elif lon1 + dt < 180 and lon1 - dt > -180:
        latmin = lat1 - dt
        latmax = lat1 + dt
        lonmin = lon1 - dt
        lonmax = lon1 + dt
        dg = dg[(dg.latitude >= latmin) & (dg.latitude <= latmax)]
        dg = dg[(dg.longitude >= lonmin) & (dg.longitude <= lonmax)]
    # With most cities roughly filtered, apply slow exact distance calculation:
    dg['dist'] = dg.apply(lambda arow: geo_dist(lat1, lon1, arow.latitude, arow.longitude), axis = 1)
    dg =  dg.sort_values('dist')
    rs = dg[:k]
    if len(rs) >= k:
        print('under bounded: ', (k, len(dg)))
        return rs
    else:
        print('over bounded: ', (k, len(rs)))
        return proximity_search(afield, avalue, k = k, dt = 2*dt)

# %%
proximity_search('name', 'Daly City', k = 10)
# Out:
# under bounded:  (10, 414)
#             id geonameid                 name            asciiname  \
# 136953  136954   5341430            Daly City            Daly City
# 136848  136849   5330854            Broadmoor            Broadmoor
# 136924  136925   5338703                Colma                Colma
# 136847  136848   5330810             Brisbane             Brisbane
# 137568  137569   5397765  South San Francisco  South San Francisco
# 137490  137491   5391959        San Francisco        San Francisco
# 137483  137484   5391749            San Bruno            San Bruno
# 137369  137370   5380420             Pacifica             Pacifica
# 137277  137278   5373129             Millbrae             Millbrae
# 136856  136857   5331920           Burlingame           Burlingame
#
#                                                  altnames   latitude  \
# 136953  Daly City,Dalyurbo,Dejli Siti,Dejli-Siti,Lungs...  37.705769
# 136848                                               None  37.686600
# 136924  Colma,Kolma,School House Station,Sutter's Fort...  37.676880
# 136847  Brisbane,Brisben,Brizbejn,Visitacion City,bris...  37.680771
# 137568  Baden,Juzhen San Francisko,Saus-San-Francisko,...  37.654659
# 137490  Franciscopolis,Frisco,Gorad San-Francyska,Kapa...  37.774929
# 137483                                               None  37.630489
# 137369  Edgemar,Fairway Park,Pacifica,Pacífica,Pasifik...  37.613831
# 137277  Milbrej,mi er bu rui,milabre,milbeule,myl bry ...  37.598549
# 136856  Berlingejm,Berlingem,Burlingejm,barlingema,beo...  37.584099
#
#          longitude feat_class feat_code country_code    ...     admin1_code  \
# 136953 -122.461922          P       PPL           US    ...              CA
# 136848 -122.482750          P       PPL           US    ...              CA
# 136924 -122.459686          P       PPL           US    ...              CA
# 136847 -122.399971          P       PPL           US    ...              CA
# 137568 -122.407753          P       PPL           US    ...              CA
# 137490 -122.419418          P     PPLA2           US    ...              CA
# 137483 -122.411079          P       PPL           US    ...              CA
# 137369 -122.486923          P       PPL           US    ...              CA
# 137277 -122.387192          P       PPL           US    ...              CA
# 136856 -122.366081          P       PPL           US    ...              CA
#
#        admin2_code admin3_code admin4_code population elevation  dem  \
# 136953         081        None        None     106562       124  123
# 136848         081        None        None       4176       106  111
# 136924         081        None        None       1520        37   36
# 136847         081        None        None       4717        33   38
# 137568         081        None        None      67271         4    5
# 137490         075        None        None     864816        16   28
# 137483         081        None        None      43185         5    5
# 137369         081        None        None      39260        25   25
# 137277         081        None        None      22795        10   10
# 136856         081        None        None      30459        12   12
#
#                    timezone    modified       dist
# 136953  America/Los_Angeles  2017-03-09   0.000354
# 136848  America/Los_Angeles  2011-05-14   2.809461
# 136924  America/Los_Angeles  2017-03-09   3.216301
# 136847  America/Los_Angeles  2017-03-09   6.114593
# 137568  America/Los_Angeles  2017-03-09   7.412851
# 137490  America/Los_Angeles  2017-03-09   8.544804
# 137483  America/Los_Angeles  2017-03-09   9.485704
# 137369  America/Los_Angeles  2017-03-09  10.450813
# 137277  America/Los_Angeles  2017-03-09  13.608368
# 136856  America/Los_Angeles  2017-03-09  15.934764
#
# [10 rows x 21 columns]

# %%
city_search('name', 'Dallas')
# Out:
#             id geonameid    name asciiname  \
# 129731  129732   4190598  Dallas    Dallas
# 132106  132107   4462896  Dallas    Dallas
# 133972  133973   4684888  Dallas    Dallas
# 138710  138711   5722064  Dallas    Dallas
#
#                                                  altnames   latitude  \
# 129731  Dalas,Dallas,dalas,dalas  jwrjya,dyalasa,Далас...  33.923710
# 132106  Dalas,Dallas,dalas,dls  karwlynay shmaly,Далас...  35.316528
# 133972  DFW,Dalas,Dalasa,Dalasas,Dallas,Dallas shaary,...  32.783058
# 138710  Dalas,Dallas,dalas,dalas  awrgn,Далас,Даллас,د...  44.919281
#
#          longitude feat_class feat_code country_code   cc2 admin1_code  \
# 129731  -84.840767          P     PPLA2           US  None          GA
# 132106  -81.176193          P       PPL           US  None          NC
# 133972  -96.806671          P     PPLA2           US  None          TX
# 138710 -123.317047          P     PPLA2           US  None          OR
#
#        admin2_code admin3_code admin4_code population elevation  dem  \
# 129731         223        None        None      12870       318  316
# 132106         071        None        None       4622       242  245
# 133972         113        None        None    1300092       128  139
# 138710         053        None        None      15277        99  101
#
#                    timezone    modified
# 129731     America/New_York  2017-03-09
# 132106     America/New_York  2017-03-09
# 133972      America/Chicago  2017-03-09
# 138710  America/Los_Angeles  2017-03-09

# %%
city_search('geonameid', 4684888)
# Out:
#             id geonameid    name asciiname  \
# 133972  133973   4684888  Dallas    Dallas
#
#                                                  altnames   latitude  \
# 133972  DFW,Dalas,Dalasa,Dalasas,Dallas,Dallas shaary,...  32.783058
#
#         longitude feat_class feat_code country_code   cc2 admin1_code  \
# 133972 -96.806671          P     PPLA2           US  None          TX
#
#        admin2_code admin3_code admin4_code population elevation  dem  \
# 133972         113        None        None    1300092       128  139
#
#                timezone    modified
# 133972  America/Chicago  2017-03-09

# %%
proximity_search('geonameid', 4684888, k = 16)
# Out:
# under bounded:  (16, 206)
#             id geonameid            name       asciiname  \
# 133972  133973   4684888          Dallas          Dallas
# 134117  134118   4697616   Highland Park   Highland Park
# 133936  133937   4682251   Cockrell Hill   Cockrell Hill
# 134146  134147   4699608        Hutchins        Hutchins
# 133993  133994   4687331     Duncanville     Duncanville
# 134027  134028   4690198  Farmers Branch  Farmers Branch
# 133825  133826   4672059   Balch Springs   Balch Springs
# 134075  134076   4694482   Grand Prairie   Grand Prairie
# 133787  133788   4669828         Addison         Addison
# 133905  133906   4679195      Carrollton      Carrollton
# 134057  134058   4693003         Garland         Garland
# 133979  133980   4685524          DeSoto          DeSoto
# 133909  133910   4679803      Cedar Hill      Cedar Hill
# 134016  134017   4689550          Euless          Euless
# 134067  134068   4693726   Glenn Heights   Glenn Heights
# 133952  133953   4683217         Coppell         Coppell
#
#                                                  altnames   latitude  \
# 133972  DFW,Dalas,Dalasa,Dalasas,Dallas,Dallas shaary,...  32.783058
# 134117                         Khajlend Park,Хайленд Парк  32.833462
# 133936                                               None  32.736240
# 134146  Khachins,hachynz  tgzas,hatshynz,Хачинс,هاتشين...  32.649300
# 133993  Dankanvil,danknfyl,danknwyl  tgzas,Данканвил,د...  32.651798
# 134027  Farmers Branch,farmrz bransh,farmrz brnch  tgz...  32.926510
# 133825                                               None  32.728741
# 134075  Deckman,Grand Prairie,Grand Preri,Grand Preris...  32.745960
# 133787  Adison,adyswn,adyswn  tgzas,Адисон,آدیسون، تگز...  32.961788
# 133905  Carrollton,Karolton,Karoltonas,Karrolton,Kerro...  32.953732
# 134057  Duck Creek,Embree,Garland,Garlandas,Garlend,Gi...  32.912621
# 133979  De Soto,DeSoto,Desoto,Opportunity,Soto,Woodlan...  32.589859
# 133909                               Cedar Hill,Cedarhill  32.588470
# 134016  Jules,ywls,ywls  tgzas,Јулес,يولس,یولس، تگزاس,...  32.837070
# 134067                                               None  32.548752
# 133952                                    Koppell,Коппелл  32.954571
#
#         longitude feat_class feat_code country_code    ...     admin1_code  \
# 133972 -96.806671          P     PPLA2           US    ...              TX
# 134117 -96.791946          P       PPL           US    ...              TX
# 133936 -96.886948          P       PPL           US    ...              TX
# 134146 -96.713051          P       PPL           US    ...              TX
# 133993 -96.908340          P       PPL           US    ...              TX
# 134027 -96.896118          P       PPL           US    ...              TX
# 133825 -96.622772          P       PPL           US    ...              TX
# 134075 -96.997780          P       PPL           US    ...              TX
# 133787 -96.829170          P       PPL           US    ...              TX
# 133905 -96.890282          P       PPL           US    ...              TX
# 134057 -96.638878          P       PPL           US    ...              TX
# 133979 -96.856949          P       PPL           US    ...              TX
# 133909 -96.956123          P       PPL           US    ...              TX
# 134016 -97.081947          P       PPL           US    ...              TX
# 134067 -96.856667          P       PPL           US    ...              TX
# 133952 -97.015007          P       PPL           US    ...              TX
#
#        admin2_code admin3_code admin4_code population elevation  dem  \
# 133972         113        None        None    1300092       128  139
# 134117         113        None        None       9189       161  169
# 133936         113        None        None       4316       195  202
# 134146         113        None        None       5727       142  146
# 133993         113        None        None      39826       221  224
# 134027         113        None        None      32689       141  147
# 133825         113        None        None      25210       152  159
# 134075         113        None        None     187809       157  162
# 133787         113        None        None      15518       194  196
# 133905         113        None        None     133168       161  163
# 134057         113        None        None     236897       168  174
# 133979         113        None        None      52486       203  205
# 133909         113        None        None      48507       253  258
# 134016         439        None        None      54219       179  184
# 134067         113        None        None      12042       206  206
# 133952         113        None        None      41159       158  169
#
#                timezone    modified       dist
# 133972  America/Chicago  2017-03-09   0.000277
# 134117  America/Chicago  2017-03-09   5.767539
# 133936  America/Chicago  2017-03-09   9.129504
# 134146  America/Chicago  2017-03-09  17.249510
# 133993  America/Chicago  2017-03-09  17.410217
# 134027  America/Chicago  2017-03-09  17.995761
# 133825  America/Chicago  2017-03-09  18.215038
# 134075  America/Chicago  2017-03-09  18.328083
# 133787  America/Chicago  2017-03-09  19.972242
# 133905  America/Chicago  2017-03-09  20.509071
# 134057  America/Chicago  2017-03-09  21.276127
# 133979  America/Chicago  2017-03-09  21.978142
# 133909  America/Chicago  2017-03-09  25.748075
# 134016  America/Chicago  2017-03-09  26.401677
# 134067  America/Chicago  2017-03-09  26.453960
# 133952  America/Chicago  2017-03-09  27.228432
#
# [16 rows x 21 columns]

# %% [markdown]
# ### How fast are radix tries for memory optimized name lookups?
# ---

# %%
import marisa_trie

# %%
keys = df.name.values.tolist()
vals = df.geonameid.values.tolist()
kvs = list(zip(keys, vals))
tkvs = list(zip(keys, [(x,) for x in vals]))

# %%
trie = marisa_trie.RecordTrie('<L', tkvs)

# %%
'San Juan de Mata' in trie, trie['San Juan de Mata']
# Out:
# (True, [(1689220,)])

# %%
# %timeit trie['San Juan de Mata']
# 2.4 µs ± 72.2 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# Out:
# 2.4 µs ± 72.2 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
adict = dict(kvs)

# %%
'San Juan de Mata' in adict, adict['San Juan de Mata']
# Out:
# (True, 1689220)

# %%
# %timeit adict['San Juan de Mata']
# 53.9 ns ± 1.74 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
# Out:
# 53.9 ns ± 1.74 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %% [markdown]
# ### Pandas Multi-Index vs Multiple Single Indexers?
# ---

# %% [markdown]
# #### Observation, Pandas isn't memory efficient with multiple single indexes.  (copies data rather than pointing at slices)

# %%
df.head(4)

# %%
df_latlon = df.set_index(['latitude','longitude'])
df_latlon.head(4)

# %%
df_pop = df.set_index(['population'])
df_pop.head(4)

# %%
df_geonameid = df.set_index(['geonameid'])
df_geonameid.head(4)

# %% [markdown]
# ### To database:
# ---

# %%
import sqlalchemy as sa

# %%
engine = sa.create_engine('mysql+mysqldb://root:citysearch123456@127.0.0.1:3306/test?charset=utf8', encoding = 'utf8')

# %%
df.to_sql('City', engine.connect(), if_exists = 'append', index = False, chunksize = 10**4)

# %%
engine = sa.create_engine('mysql+mysqldb://root:user@172.17.0.3:9306/test?charset=utf8', encoding = 'utf8')

# %%
df.to_sql('City', engine.connect(), if_exists = 'append', index = False, chunksize = 10**4)

# %% [markdown]
# #### SQLAlchemy is screwing up the connection, always better to go direct to the driver...

# %%
import logger
import mariadb
imp.reload(mariadb)
from mariadb import SQL

# %%
mysql = SQL(user = 'gone', passwd = 'gone')

# %%
mysql.fetchall('show tables;')

# %%
sphinx = SQL(host = '172.17.0.3', port = 9306)

# %%
sphinx.fetchall('show tables')

# %%
dfmin = df.name + ',' + df.asciiname + ',' + df.alternatenames
dfmin = pd.DataFrame(dfmin, columns = ['altnames'])
dfmin.to_csv('data/city_altnames.tsv', sep = '\t', index = True, index_label = 'id')
dfmin.head()

# %%
import sphinxql
imp.reload(sphinxql)
from sphinxql import SphinxQL

# %%
sphinx = SphinxQL(host = '172.17.0.3')

# %%
sphinx.fetchall('show tables')

# %% [markdown]
# ### JSON Cache:
# ---

# %%
df.head(1).to_json(orient = 'records', lines = True)
# Out:
# '{"id":1,"geonameid":3039154,"name":"El Tarter","asciiname":"El Tarter","altnames":"Ehl Tarter,\\u042d\\u043b \\u0422\\u0430\\u0440\\u0442\\u0435\\u0440","latitude":42.5795211792,"longitude":1.6536200047,"feat_class":"P","feat_code":"PPL","country_code":"AD","cc2":null,"admin1_code":"02","admin2_code":null,"admin3_code":null,"admin4_code":null,"population":1052,"elevation":null,"dem":1721,"timezone":"Europe\\/Andorra","modified":"2012-11-03"}'

# %%
df1 = df.head(100)

# %%
# %timeit df1.to_json(orient = 'records', lines = True)
# Out:
# 853 µs ± 7.38 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df['json'] = df.apply(lambda row: row.to_json(orient = 'records'))

# %%
for i in range(10):
    jstr += df.iloc[i].to_json(orient = 'records', lines = True)

# %% [markdown]
# ### Geo Lookups:
# ---

# %%
geo2 = df.set_index(['latitude','longitude'])[['id']].sort_index(level = (0, 1))

# %%
geo2.head(8)

# %%
geo2.loc[42.544:42.545]

# %% [markdown]
# ##### Problem, pandas doesn't do multilevel range slices...

# %%
# Try two in memory pandas indexes... (other options on the table: radix tries, judy arrays, lsm trees)
geo = (df.set_index(['longitude'])[['id']], df.set_index(['longitude'])[['id']])

# %%
def geo_search(lat, lon, dt = 2):
    id_lonf = geo[1].iloc[lon - dt:lon + dt].id
    id_latf = geo[0].iloc[lat - dt:lat + dt].id
    return set(id_lonf).intersection(id_latf)

# %% [markdown]
# #### RTrees...

# %%
from rtree import index as rtree

# %%
rgeo = rtree.Rtree()

# %%
geo = df[['id','longitude','latitude']]
geo.head(4)
# Out:
#    id  longitude   latitude
# 0   1    1.65362  42.579521
# 1   2    1.49129  42.463718
# 2   3    1.73361  42.542770
# 3   4    1.53319  42.556229

# %%
rgeo = rtree.Rtree()
for i in range(1,len(geo)):
    rgeo.insert(i, (geo.iloc[i][1:].tolist()))
print(rgeo)
# Out:
# <rtree.index.Index object at 0x7f2963b5d0f0>

# %%
SF = (-122.41,37.77)
dt = 0.1
ids = list(rgeo.intersection((SF[0]-dt,SF[1]-dt,SF[0]+dt,SF[1]+dt)))
print(len(ids), ids[:10])
# Out:
# 7 [137254, 136924, 136847, 136848, 136953, 137490, 137530]

# %%
df.loc[ids]
# Out:
#             id geonameid           name      asciiname  \
# 137254  137255   5370464     Marin City     Marin City
# 136924  136925   5338703          Colma          Colma
# 136847  136848   5330810       Brisbane       Brisbane
# 136848  136849   5330854      Broadmoor      Broadmoor
# 136953  136954   5341430      Daly City      Daly City
# 137490  137491   5391959  San Francisco  San Francisco
# 137530  137531   5393611      Sausalito      Sausalito
#
#                                                  altnames   latitude  \
# 137254        Marin Siti,Marin-Siti,Марин Сити,Марин-Сити  37.868542
# 136924  Colma,Kolma,School House Station,Sutter's Fort...  37.676880
# 136847  Brisbane,Brisben,Brizbejn,Visitacion City,bris...  37.680771
# 136848                                               None  37.686600
# 136953  Daly City,Dalyurbo,Dejli Siti,Dejli-Siti,Lungs...  37.705769
# 137490  Franciscopolis,Frisco,Gorad San-Francyska,Kapa...  37.774929
# 137530  El Ojo la Agua de Zaucito,JMC,Saucelito,Saucet...  37.859089
#
#          longitude feat_class feat_code country_code ...  admin1_code  \
# 137254 -122.509140          P       PPL           US ...           CA
# 136924 -122.459686          P       PPL           US ...           CA
# 136847 -122.399971          P       PPL           US ...           CA
# 136848 -122.482750          P       PPL           US ...           CA
# 136953 -122.461922          P       PPL           US ...           CA
# 137490 -122.419418          P     PPLA2           US ...           CA
# 137530 -122.485252          P       PPL           US ...           CA
#
#        admin2_code admin3_code admin4_code population elevation  dem  \
# 137254         041        None        None       2666         7    9
# 136924         081        None        None       1520        37   36
# 136847         081        None        None       4717        33   38
# 136848         081        None        None       4176       106  111
# 136953         081        None        None     106562       124  123
# 137490         075        None        None     864816        16   28
# 137530         041        None        None       7156         4    2
#
#                    timezone    modified json
# 137254  America/Los_Angeles  2011-05-14  NaN
# 136924  America/Los_Angeles  2017-03-09  NaN
# 136847  America/Los_Angeles  2017-03-09  NaN
# 136848  America/Los_Angeles  2011-05-14  NaN
# 136953  America/Los_Angeles  2017-03-09  NaN
# 137490  America/Los_Angeles  2017-03-09  NaN
# 137530  America/Los_Angeles  2017-03-09  NaN
#
# [7 rows x 21 columns]

# %%
# %timeit rgeo.intersection((SF[0]-dt,SF[1]-dt,SF[0]+dt,SF[1]+dt))
# Out:
# 80 µs ± 835 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit df.loc[ids]
# Out:
# 615 µs ± 13.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df.loc[rgeo.nearest(SF, 10)]
# Out:
#             id geonameid                 name            asciiname  \
# 137490  137491   5391959        San Francisco        San Francisco
# 136953  136954   5341430            Daly City            Daly City
# 136847  136848   5330810             Brisbane             Brisbane
# 136924  136925   5338703                Colma                Colma
# 136848  136849   5330854            Broadmoor            Broadmoor
# 137610  137611   5402535              Tiburon              Tiburon
# 137568  137569   5397765  South San Francisco  South San Francisco
# 136810  136811   5327490            Belvedere            Belvedere
# 137530  137531   5393611            Sausalito            Sausalito
# 137019  137020   5346462           Emeryville           Emeryville
#
#                                                  altnames   latitude  \
# 137490  Franciscopolis,Frisco,Gorad San-Francyska,Kapa...  37.774929
# 136953  Daly City,Dalyurbo,Dejli Siti,Dejli-Siti,Lungs...  37.705769
# 136847  Brisbane,Brisben,Brizbejn,Visitacion City,bris...  37.680771
# 136924  Colma,Kolma,School House Station,Sutter's Fort...  37.676880
# 136848                                               None  37.686600
# 137610  E-Tiburon,Tiberon,Tiburon,Tiburón,di bo long,t...  37.873539
# 137568  Baden,Juzhen San Francisko,Saus-San-Francisko,...  37.654659
# 136810  Belvedere,Belvedir,bei er wei dai lei,belabhed...  37.872700
# 137530  El Ojo la Agua de Zaucito,JMC,Saucelito,Saucet...  37.859089
# 137019  Emerivil,Emerivill,Emerivill',Emeryville,Golde...  37.831322
#
#          longitude feat_class feat_code country_code ...  admin1_code  \
# 137490 -122.419418          P     PPLA2           US ...           CA
# 136953 -122.461922          P       PPL           US ...           CA
# 136847 -122.399971          P       PPL           US ...           CA
# 136924 -122.459686          P       PPL           US ...           CA
# 136848 -122.482750          P       PPL           US ...           CA
# 137610 -122.456642          P       PPL           US ...           CA
# 137568 -122.407753          P       PPL           US ...           CA
# 136810 -122.464417          P       PPL           US ...           CA
# 137530 -122.485252          P       PPL           US ...           CA
# 137019 -122.285248          P       PPL           US ...           CA
#
#        admin2_code admin3_code admin4_code population elevation  dem  \
# 137490         075        None        None     864816        16   28
# 136953         081        None        None     106562       124  123
# 136847         081        None        None       4717        33   38
# 136924         081        None        None       1520        37   36
# 136848         081        None        None       4176       106  111
# 137610         041        None        None       9214         4    2
# 137568         081        None        None      67271         4    5
# 136810         041        None        None       2121        11   15
# 137530         041        None        None       7156         4    2
# 137019         001        None        None      11694         7   10
#
#                    timezone    modified json
# 137490  America/Los_Angeles  2017-03-09  NaN
# 136953  America/Los_Angeles  2017-03-09  NaN
# 136847  America/Los_Angeles  2017-03-09  NaN
# 136924  America/Los_Angeles  2017-03-09  NaN
# 136848  America/Los_Angeles  2011-05-14  NaN
# 137610  America/Los_Angeles  2017-03-09  NaN
# 137568  America/Los_Angeles  2017-03-09  NaN
# 136810  America/Los_Angeles  2017-03-09  NaN
# 137530  America/Los_Angeles  2017-03-09  NaN
# 137019  America/Los_Angeles  2017-03-09  NaN
#
# [10 rows x 21 columns]

# %%
# %timeit rgeo.nearest(SF, 10)
# Out:
# 278 µs ± 2.36 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
